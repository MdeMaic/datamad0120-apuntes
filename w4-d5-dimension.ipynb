# %% [markdown]
# # X = imagen
# shape === (70000, 784)
#
# 784 pixeles por cada imagen.
#
# 784 = columnas = Dimensiones == Experimentos de 70000 samples.
#
# Si conoces la distribución que tiene cada pixel en cada uno de los 70000 samples. Sabes como se comporta en cada número.
#
# plt.xlim genera los límites menor y mayor de cada eje.

# %%
%
import numpy as np
import matplotlib.pyplot as plt

x = np.random.randn(1000)
y = np.random.randn(1000)

plt.plot(x,y,"o")

# %% [markdown]
# # y = resultado de la imagen. GROUNDTRUTH!

# %% [markdown]
# ## Para reducir la dimensionalidad.
# #from sklearn.decomposition import PCA
#
# #n_components = a la dimensión que se quiere reducir:
# pca = PCA(n_components=2)
#
# #para ejecutar el código.
# pca.fit(data)
#
# #funciona mejor
# pca.fit_transform(data)
#
# Reduce de (13861,784) a (13861,2) --> 2 dimensiones

# %% [markdown]
# ## Al reducir el modelo, demostramos que, si con 2 dimensiones existe una separación visual entre los datos. El entrenamiento del modelo es más rápido y sencillo.

# %% [markdown]
# # MACHINE LEARNING ES JUGAR AL QUIEN ES QUIEN!
